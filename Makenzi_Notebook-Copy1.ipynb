# %%
# %load_ext autoreload
# %autoreload 2

# This tells Python to show the plots inside this notebook.
# %matplotlib inline
# We have to import the plotting library into this Jupyter notebook
# We only have to do this once (unless you close and open the notebook,
# then you'll have to do it again)
import matplotlib.pyplot as plt
import itertools
import pandas

# %%
nasa_astronaut_dataset = pandas.read_csv("astronauts.csv")
print (nasa_astronaut_dataset.head) #First 10 rows
# Out:
# <bound method NDFrame.head of                       Name    Year  Group   Status Birth Date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active  5/17/1967
# 1           Loren W. Acton     NaN    NaN  Retired   3/7/1936
# 2         James C. Adamson  1984.0   10.0  Retired   3/3/1946
# 3          Thomas D. Akers  1987.0   12.0  Retired  5/20/1951
# 4              Buzz Aldrin  1963.0    3.0  Retired  1/20/1930
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356        George D. Zamka  1998.0   17.0  Retired  6/29/1962
#
#            Birth Place Gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# 4        Montclair, NJ   Male
# ..                 ...    ...
# 352   Indianapolis, IN   Male
# 353        Chicago, IL   Male
# 354        Jackson, MI   Male
# 355  San Francisco, CA   Male
# 356    Jersey City, NJ   Male
#
#                                             Alma Mater  \
# 0    University of California-Santa Barbara; Univer...
# 1     Montana State University; University of Colorado
# 2            US Military Academy; Princeton University
# 3                         University of Missouri-Rolla
# 4                             US Military Academy; MIT
# ..                                                 ...
# 352              Purdue University; Indiana University
# 353  MIT; University of Texas-Austin; George Washin...
# 354        US Military Academy; University of Michigan
# 355                    Georgia Institute of Technology
# 356  US Naval Academy; Florida Institute of Technology
#
#           Undergraduate Major                            Graduate Major  \
# 0                     Geology                                   Geology
# 1         Engineering Physics                             Solar Physics
# 2                 Engineering                     Aerospace Engineering
# 3         Applied Mathematics                       Applied Mathematics
# 4      Mechanical Engineering                              Astronautics
# ..                        ...                                       ...
# 352    Electrical Engineering                                  Medicine
# 353                   Physics              Physics; Business Management
# 354          Military Science  Aeronautical & Astronautical Engineering
# 355  Aeronautical Engineering                                       NaN
# 356               Mathematics                    Engineering Management
#
#     Military Rank            Military Branch  Space Flights  \
# 0             NaN                        NaN              2
# 1             NaN                        NaN              1
# 2         Colonel          US Army (Retired)              2
# 3         Colonel     US Air Force (Retired)              4
# 4         Colonel     US Air Force (Retired)              2
# ..            ...                        ...            ...
# 352           NaN                        NaN              3
# 353     Commander                    US Navy              0
# 354       Colonel     US Air Force (Retired)              1
# 355       Captain          US Navy (Retired)              6
# 356       Colonel  US Marine Corps (Retired)              2
#
#      Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0                 3307            2              13.0
# 1                  190            0               0.0
# 2                  334            0               0.0
# 3                  814            4              29.0
# 4                  289            2               8.0
# ..                 ...          ...               ...
# 352               4044            7              41.0
# 353                  0            0               0.0
# 354                295            1               0.5
# 355                835            3              20.0
# 356                692            0               0.0
#
#                                               Missions Death Date  \
# 0               STS-119 (Discovery), ISS-31/32 (Soyuz)        NaN
# 1                                STS 51-F (Challenger)        NaN
# 2                 STS-28 (Columbia), STS-43 (Atlantis)        NaN
# 3    STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...        NaN
# 4                                 Gemini 12, Apollo 11        NaN
# ..                                                 ...        ...
# 352  STS-58 (Columbia). STS-86/89 (Atlantis/Endeavo...        NaN
# 353                                                NaN        NaN
# 354                                          Apollo 15        NaN
# 355  Gemini 3, Gemini 10, Apollo 10, Apollo 16, STS...        NaN
# 356            STS-120 (Discovery), STS-130 (Endeavor)        NaN
#
#     Death Mission
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 352           NaN
# 353           NaN
# 354           NaN
# 355           NaN
# 356           NaN
#
# [357 rows x 19 columns]>

# %%
row = nasa_astronaut_dataset["Space Flight (hr)"].idxmax()
astronaut = nasa_astronaut_dataset["Name"][row]
hours = nasa_astronaut_dataset["Space Flight (hr)"][row]

print(f"{astronaut} has the most flight hours with a total of {hours} hours.")
# Out:
# Jeffrey N. Williams has the most flight hours with a total of 12818 hours.

# %%
gender_occurrence = nasa_astronaut_dataset.groupby('Gender').count()
gender_military = gender_occurrence["Military Rank"]
gender_occurrence_name = gender_occurrence["Name"]
print (gender_military)
#print (gender_occurrence)
#print (gender_occurrence_name)
# Out:
# Gender
# Female     13
# Male      194
# Name: Military Rank, dtype: int64

# %%
#gender = nasa_astronaut_dataset["Gender"]
gender = ["Female", "Male"]
count_row = nasa_astronaut_dataset.shape[0]
print (gender)
# Out:
# ['Female', 'Male']

# %%
plt.style.use("ggplot")
plt.bar(gender, gender_occurrence_name, width=0.8, label='Civilian', color='silver')
plt.bar(gender, gender_military, width = 0.8, label = 'Military', color = 'gold')
plt.xlabel("Gender")
plt.ylabel("Number of Astronauts")
plt.title("Gender Distribution of Astronauts")

plt.legend(loc="upper left")
plt.show()

# %%
#Age at selection
birth_date = nasa_astronaut_dataset["Birth Date"]
birth_years_list = []
selection_years_list = []
selection_age_list = []

def get_birth_years_list(birth_date):
    """
    Extracts the year from the D.O.B. column of the dataset and creates a list.
    
    args:
        birth_date: the "Birth Date" column of the dataset
        
    return:
        birth_years_list: a list of the birth years 
    """
    for i in birth_date:
        birth_year = int(i[-4:])
        birth_years_list.append(birth_year)

    return birth_years_list

selection_year = nasa_astronaut_dataset["Year"]

def get_selection_years_list(selection_year):
    """
    Create a list of the astronaut selection years.
    
    args:
        selection_year: the "Year" column of the dataset.
    
    return:
        selection_years_list: a list of all of the selection years.
    """
    for i in selection_year:
        selection_years_list.append(i)
        
    return selection_years_list

def get_selection_age(birth_date, selection_year):
    """
    """
    birth_year = get_birth_years_list(birth_date)
    year_of_selection = get_selection_years_list(selection_year)
    
    for i in birth_year:
        for j in year_of_selection:
            if j == None:
                selection_age_list.append("N/A")
                break
            else:
                selection_age_list.append(j-i)
                break

    return selection_age_list

print (get_selection_age(birth_date, selection_year))
#print (get_selection_years_list(selection_year))
# Out:
# [37.0, 68.0, 58.0, 53.0, 74.0, 49.0, 67.0, 45.0, 71.0, 45.0, 45.0, 37.0, 55.0, 44.0, 74.0, 41.0, 50.0, 28.0, 52.0, 51.0, 51.0, 45.0, 51.0, 60.0, 73.0, 72.0, 34.0, 62.0, 45.0, 62.0, 67.0, 40.0, 58.0, 76.0, 40.0, 48.0, 53.0, 73.0, 61.0, 37.0, 61.0, 48.0, 48.0, 53.0, 59.0, 48.0, 70.0, 43.0, 47.0, 55.0, 45.0, 46.0, 35.0, 52.0, 55.0, 47.0, 79.0, 72.0, 57.0, 61.0, 34.0, 56.0, 70.0, 69.0, 42.0, 54.0, 69.0, 43.0, 44.0, 50.0, 43.0, 57.0, 52.0, 58.0, 54.0, 44.0, 45.0, 74.0, 74.0, 77.0, 58.0, 45.0, 61.0, 67.0, 64.0, 55.0, 72.0, 42.0, 46.0, 51.0, 54.0, 42.0, 51.0, 69.0, 55.0, 61.0, 36.0, 46.0, 74.0, 62.0, 72.0, 34.0, 71.0, 65.0, 43.0, 48.0, 39.0, 37.0, 30.0, 55.0, 58.0, 47.0, 44.0, 47.0, 47.0, 47.0, 74.0, 43.0, 68.0, 58.0, 43.0, 56.0, 56.0, 72.0, 74.0, 49.0, 48.0, 68.0, 58.0, 74.0, 83.0, 52.0, 42.0, 75.0, 47.0, 59.0, 73.0, 63.0, 47.0, 65.0, 78.0, 46.0, 53.0, 71.0, 48.0, 40.0, 52.0, 48.0, 48.0, 58.0, 71.0, 63.0, 53.0, 46.0, 78.0, 52.0, 52.0, 42.0, 46.0, 49.0, 40.0, 54.0, 45.0, 43.0, 60.0, 65.0, 36.0, 47.0, 59.0, 38.0, 47.0, 74.0, 53.0, 60.0, 48.0, 45.0, 46.0, 50.0, 42.0, 49.0, 45.0, 40.0, 40.0, 40.0, 72.0, 43.0, 37.0, 41.0, 48.0, 45.0, 52.0, 55.0, 65.0, 53.0, 56.0, 74.0, 31.0, 44.0, 49.0, 47.0, 47.0, 71.0, 48.0, 46.0, 44.0, 58.0, 68.0, 39.0, 76.0, 48.0, 41.0, 61.0, 40.0, 44.0, 42.0, 44.0, 68.0, 33.0, 53.0, 56.0, 61.0, 67.0, 43.0, 61.0, 75.0, 52.0, 54.0, 54.0, 55.0, 43.0, 40.0, 29.0, 70.0, 74.0, 53.0, 52.0, 59.0, 69.0, 58.0, 62.0, 54.0, 48.0, 45.0, 41.0, 35.0, 58.0, 64.0, 46.0, 39.0, 38.0, 58.0, 53.0, 68.0, 52.0, 43.0, 53.0, 68.0, 40.0, 44.0, 56.0, 71.0, 49.0, 53.0, 74.0, 43.0, 48.0, 49.0, 52.0, 53.0, 50.0, 36.0, 55.0, 40.0, 58.0, 53.0, 41.0, 49.0, 48.0, 71.0, 56.0, 26.0, 52.0, 55.0, 39.0, 81.0, 69.0, 69.0, 65.0, 72.0, 54.0, 60.0, 48.0, 57.0, 77.0, 52.0, 49.0, 59.0, 81.0, 55.0, 60.0, 80.0, 59.0, 46.0, 60.0, 62.0, 74.0, 41.0, 62.0, 42.0, 43.0, 53.0, 44.0, 73.0, 43.0, 54.0, 61.0, 53.0, 49.0, 51.0, 52.0, 75.0, 49.0, 39.0, 67.0, 72.0, 60.0, 38.0, 60.0, 37.0, 55.0, 48.0, 42.0, 56.0, 60.0, 39.0, 49.0, 64.0, 42.0, 72.0, 52.0, 44.0, 74.0, 44.0, 55.0, 72.0, 46.0, 46.0, 39.0, 42.0, 38.0, 29.0, 46.0, 48.0, 42.0, 72.0, 74.0, 42.0]

# %%
birth_date = nasa_astronaut_dataset["Birth Date"]
selection_year = nasa_astronaut_dataset["Year"]

nasa_astronaut_dataset['Birth Date'] = nasa_astronaut_dataset['Birth Date'].str[-4:]

nasa_astronaut_dataset["Selection Year"] = selection_year
nasa_astronaut_dataset

selectioner = nasa_astronaut_dataset["Selection Year"]

print(len(nasa_astronaut_dataset.iloc[:,1]))



for i in range(len(nasa_astronaut_dataset.iloc[:,1])):
    if nasa_astronaut_dataset.iloc[i,1] == 1984.0:
        print(nasa_astronaut_dataset.iloc[i,0])
    pass

nasa_astronaut_dataset
# Out:
# 357
# James C. Adamson
# Ellen S. Baker
# Mark N. Brown
# Kenneth D. Cameron
# Manley Lanier Carter Jr.
# John H. Casper
# Frank L. Culbertson Jr.
# Sidney M. Gutierrez
# L. Blaine Hammond Jr.
# Marsha S. Ivins
# Mark C. Lee
# G. David Low
# Michael J. McCulley
# James A. McDivitt
# William M. Shepherd
# Kathryn C. Thornton
# Charles Lacy Veach
# James D. Wetherbee
#                       Name    Year  Group   Status Birth Date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active       1967
# 1           Loren W. Acton     NaN    NaN  Retired       1936
# 2         James C. Adamson  1984.0   10.0  Retired       1946
# 3          Thomas D. Akers  1987.0   12.0  Retired       1951
# 4              Buzz Aldrin  1963.0    3.0  Retired       1930
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired       1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired       1962
# 354       Alfred M. Worden  1966.0    5.0  Retired       1932
# 355          John W. Young  1962.0    2.0  Retired       1930
# 356        George D. Zamka  1998.0   17.0  Retired       1962
#
#            Birth Place Gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# 4        Montclair, NJ   Male
# ..                 ...    ...
# 352   Indianapolis, IN   Male
# 353        Chicago, IL   Male
# 354        Jackson, MI   Male
# 355  San Francisco, CA   Male
# 356    Jersey City, NJ   Male
#
#                                             Alma Mater  \
# 0    University of California-Santa Barbara; Univer...
# 1     Montana State University; University of Colorado
# 2            US Military Academy; Princeton University
# 3                         University of Missouri-Rolla
# 4                             US Military Academy; MIT
# ..                                                 ...
# 352              Purdue University; Indiana University
# 353  MIT; University of Texas-Austin; George Washin...
# 354        US Military Academy; University of Michigan
# 355                    Georgia Institute of Technology
# 356  US Naval Academy; Florida Institute of Technology
#
#           Undergraduate Major                            Graduate Major  \
# 0                     Geology                                   Geology
# 1         Engineering Physics                             Solar Physics
# 2                 Engineering                     Aerospace Engineering
# 3         Applied Mathematics                       Applied Mathematics
# 4      Mechanical Engineering                              Astronautics
# ..                        ...                                       ...
# 352    Electrical Engineering                                  Medicine
# 353                   Physics              Physics; Business Management
# 354          Military Science  Aeronautical & Astronautical Engineering
# 355  Aeronautical Engineering                                       NaN
# 356               Mathematics                    Engineering Management
#
#     Military Rank            Military Branch  Space Flights  \
# 0             NaN                        NaN              2
# 1             NaN                        NaN              1
# 2         Colonel          US Army (Retired)              2
# 3         Colonel     US Air Force (Retired)              4
# 4         Colonel     US Air Force (Retired)              2
# ..            ...                        ...            ...
# 352           NaN                        NaN              3
# 353     Commander                    US Navy              0
# 354       Colonel     US Air Force (Retired)              1
# 355       Captain          US Navy (Retired)              6
# 356       Colonel  US Marine Corps (Retired)              2
#
#      Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0                 3307            2              13.0
# 1                  190            0               0.0
# 2                  334            0               0.0
# 3                  814            4              29.0
# 4                  289            2               8.0
# ..                 ...          ...               ...
# 352               4044            7              41.0
# 353                  0            0               0.0
# 354                295            1               0.5
# 355                835            3              20.0
# 356                692            0               0.0
#
#                                               Missions Death Date  \
# 0               STS-119 (Discovery), ISS-31/32 (Soyuz)        NaN
# 1                                STS 51-F (Challenger)        NaN
# 2                 STS-28 (Columbia), STS-43 (Atlantis)        NaN
# 3    STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...        NaN
# 4                                 Gemini 12, Apollo 11        NaN
# ..                                                 ...        ...
# 352  STS-58 (Columbia). STS-86/89 (Atlantis/Endeavo...        NaN
# 353                                                NaN        NaN
# 354                                          Apollo 15        NaN
# 355  Gemini 3, Gemini 10, Apollo 10, Apollo 16, STS...        NaN
# 356            STS-120 (Discovery), STS-130 (Endeavor)        NaN
#
#     Death Mission  Selection Year
# 0             NaN          2004.0
# 1             NaN             NaN
# 2             NaN          1984.0
# 3             NaN          1987.0
# 4             NaN          1963.0
# ..            ...             ...
# 352           NaN          1990.0
# 353           NaN          1998.0
# 354           NaN          1966.0
# 355           NaN          1962.0
# 356           NaN          1998.0
#
# [357 rows x 20 columns]

# %%
nasa_astronaut_dataset.dtypes

nasa_astronaut_dataset.astype({"Birth Date" : "float64"}).dtypes
# Out:
# Name                    object
# Year                   float64
# Group                  float64
# Status                  object
# Birth Date             float64
# Birth Place             object
# Gender                  object
# Alma Mater              object
# Undergraduate Major     object
# Graduate Major          object
# Military Rank           object
# Military Branch         object
# Space Flights            int64
# Space Flight (hr)        int64
# Space Walks              int64
# Space Walks (hr)       float64
# Missions                object
# Death Date              object
# Death Mission           object
# dtype: object

# %%
colleges = nasa_astronaut_dataset.iloc[:,7]

list(colleges)

college_list = []

for i in colleges:
    i = str(i)
    split_list = i.split(";")
    college_list += split_list
    

college_frequency = {}

for college in college_list:
    if college not in college_frequency:
        college_frequency[college] = 1
    else:
        college_frequency[college] += 1
print(college_frequency)
# Out:
# {'University of California-Santa Barbara': 1, ' University of Arizona': 4, 'Montana State University': 1, ' University of Colorado': 8, 'US Military Academy': 18, ' Princeton University': 3, 'University of Missouri-Rolla': 2, ' MIT': 24, 'Villanova University': 1, ' University of Florida': 5, 'DePauw University': 1, ' Yale University': 1, 'University of Illinois': 5, ' US Naval Postgraduate School': 31, 'US Naval Academy': 52, ' Air Force Institute of Technology': 5, 'Hastings College': 1, ' Iowa State University': 1, 'University of Washington': 5, ' Creighton University': 1, 'MIT': 12, ' University of Washington': 6, 'Harvard University': 2, 'University of Illinois-Urbana': 1, 'Purdue University': 15, ' University of Southern California': 8, 'Frostburg State University': 1, ' University of Maryland': 5, 'University of Idaho': 1, ' University of Tennessee': 6, 'George Washington University': 1, ' University of Texas': 7, 'Drexel University': 3, ' Thomas Jefferson University': 1, 'State University of New York-Buffalo': 1, ' Cornell University': 4, 'University of Texas': 6, ' Northwestern University': 2, ' Wright State University': 1, 'Cornell University': 5, ' University of Miami': 1, 'Lehigh University': 2, ' Georgetown University': 2, 'Texas Technological College': 1, 'Washington University': 1, ' California Institute of Technology': 8, 'US Air Force Academy': 38, ' Purdue University': 8, ' Old Dominion University': 1, 'Pennsylvania State University': 3, ' University of Houston-Clear Lake': 6, ' Georgia Institute of Technology': 10, ' Columbia University': 5, 'University of North Carolina at Chapel Hill': 1, ' Duke University': 1, 'University of Colorado': 8, ' University of California Los Angeles': 1, 'University of Wisconsin': 2, 'The Citadel': 1, ' University of Tennessee-Knoxville': 3, 'College of William & Mary': 1, ' Eastern Virginia Medical School': 1, ' University of West Florida': 4, 'Rice University': 2, ' Stanford University': 15, 'US Coast Guard Academy': 2, ' Embry-Riddle Aeronautical University': 4, 'San Francisco State University': 1, 'University of Arizona': 2, ' University of Central Florida': 2, 'California State University-Fullerton': 1, ' University of California-Davis': 1, 'Polytechnic Institute of Brooklyn': 1, ' George Washington University': 6, ' Virginia Polytechnic Institute': 2, ' Michigan State University': 1, 'University of Minnesota-Minneapolis': 1, 'University of Southern California': 2, 'Emory University': 1, ' Rutgers University': 3, 'California Polytechnic State University': 2, 'University of Connecticut': 2, 'University of Sydney': 2, 'Punjab Engineering College': 1, ' University of Texas-Arlington': 2, 'University of California-Berkeley': 5, ' University of California-Santa Barbara': 2, 'University of Wisconsin-Madison': 1, 'Colorado State University': 2, ' Utah State University': 1, ' University of Massachusetts': 1, 'Syracuse University': 2, ' Webster University': 1, 'Princeton University': 2, 'Air Force Institute of Technology': 1, 'Loyola College': 1, 'Tennessee Polytechnic Institute': 1, 'University of California-Los Angeles': 3, 'Ohio State University': 1, ' University of Houston': 7, 'Georgia Institute of Technology': 4, ' Auburn University': 1, ' University of Alabama-Huntsville': 1, 'University of Alabama at Birmingham': 1, 'California State University': 1, ' US Air Force Institute of Technology': 6, 'University of Kansas': 3, 'LeMoyne College': 1, 'Washington State University': 1, ' Colorado State University': 3, ' Queen’s University-Canada': 1, 'Stanford University': 7, 'Cambridge University': 1, 'University of Notre Dame': 3, ' Troy State University': 4, ' University of Virginia': 5, 'Texas A&M University': 1, ' University of Michigan': 5, 'California Institute of Technology': 3, ' University of New Mexico': 1, 'State University of New York': 1, 'University of Utah': 2, 'University of Oklahoma': 3, 'Vanderbilt University': 1, ' University of Pennsylvania': 1, 'University of Roch ...

# %%
new ={k: v for k, v in sorted(college_frequency.items(), key=lambda item: item[1], reverse = True)}

# %%
new
# Out:
# {'US Naval Academy': 52,
#  'US Air Force Academy': 38,
#  ' US Naval Postgraduate School': 31,
#  ' MIT': 24,
#  'US Military Academy': 18,
#  'Purdue University': 15,
#  ' Stanford University': 15,
#  'MIT': 12,
#  ' Georgia Institute of Technology': 10,
#  ' University of Colorado': 8,
#  ' University of Southern California': 8,
#  ' California Institute of Technology': 8,
#  ' Purdue University': 8,
#  'University of Colorado': 8,
#  ' University of Texas': 7,
#  ' University of Houston': 7,
#  'Stanford University': 7,
#  ' University of Washington': 6,
#  ' University of Tennessee': 6,
#  'University of Texas': 6,
#  ' University of Houston-Clear Lake': 6,
#  ' George Washington University': 6,
#  ' US Air Force Institute of Technology': 6,
#  ' University of Florida': 5,
#  'University of Illinois': 5,
#  ' Air Force Institute of Technology': 5,
#  'University of Washington': 5,
#  ' University of Maryland': 5,
#  'Cornell University': 5,
#  ' Columbia University': 5,
#  'University of California-Berkeley': 5,
#  ' University of Virginia': 5,
#  ' University of Michigan': 5,
#  'Auburn University': 5,
#  ' Rice University': 5,
#  ' Harvard University': 5,
#  ' University of Arizona': 4,
#  ' Cornell University': 4,
#  ' University of West Florida': 4,
#  ' Embry-Riddle Aeronautical University': 4,
#  'Georgia Institute of Technology': 4,
#  ' Troy State University': 4,
#  ' Princeton University': 3,
#  'Drexel University': 3,
#  'Pennsylvania State University': 3,
#  ' University of Tennessee-Knoxville': 3,
#  ' Rutgers University': 3,
#  'University of California-Los Angeles': 3,
#  'University of Kansas': 3,
#  ' Colorado State University': 3,
#  'University of Notre Dame': 3,
#  'California Institute of Technology': 3,
#  'University of Oklahoma': 3,
#  ' Florida Institute of Technology': 3,
#  ' University of California-Berkeley': 3,
#  ' University of California-Los Angeles': 3,
#  'University of Missouri-Rolla': 2,
#  'Harvard University': 2,
#  ' Northwestern University': 2,
#  'Lehigh University': 2,
#  ' Georgetown University': 2,
#  'University of Wisconsin': 2,
#  'Rice University': 2,
#  'US Coast Guard Academy': 2,
#  'University of Arizona': 2,
#  ' University of Central Florida': 2,
#  ' Virginia Polytechnic Institute': 2,
#  'University of Southern California': 2,
#  'California Polytechnic State University': 2,
#  'University of Connecticut': 2,
#  'University of Sydney': 2,
#  ' University of Texas-Arlington': 2,
#  ' University of California-Santa Barbara': 2,
#  'Colorado State University': 2,
#  'Syracuse University': 2,
#  'Princeton University': 2,
#  'University of Utah': 2,
#  'University of Rochester': 2,
#  ' University of Missouri': 2,
#  ' Johns Hopkins University': 2,
#  'University of Virginia': 2,
#  ' Golden Gate University': 2,
#  'Amherst College': 2,
#  'Texas Tech University': 2,
#  'US Merchant Marine Academy': 2,
#  ' University of Texas Medical Branch-Galveston': 2,
#  'University of New Hampshire': 2,
#  ' Ohio State University': 2,
#  'University of Michigan': 2,
#  'Harvey Mudd College': 2,
#  ' Rensselaer Polytechnic Institute': 2,
#  ' California State University-Fresno': 2,
#  ' West Florida University': 2,
#  'Carnegie-Mellon University': 2,
#  'Oregon State University': 2,
#  ' Texas A&M University': 2,
#  ' US Naval War College': 2,
#  'Florida State University': 2,
#  'University of California-Santa Barbara': 1,
#  'Montana State University': 1,
#  'Villanova University': 1,
#  'DePauw University': 1,
#  ' Yale University': 1,
#  'Hastings College': 1,
#  ' Iowa State University': 1,
#  ' Creighton University': 1,
#  'University of Illinois-Urbana': 1,
#  'Frostburg State University': 1,
#  'University of Idaho': 1,
#  'George Washington University': 1,
#  ' Thomas Jefferson University': 1,
#  'State University of New York-Buffalo': 1,
#  ' Wright State University': 1,
#  ' University of Miami': 1,
#  'Texas Technological College': 1,
#  'Washington University': 1,
#  ' Old Dominion University': 1,
#  'University of North Carolina at Chapel Hill': 1,
#  ' Duke University': 1,
#  ' University of California Los Angeles': 1,
#  'The Citadel': 1,
#  'College of William & Mary': 1,
#  ' Eastern Virginia Medical School': 1,
#  'San Francisco State University': 1,
#  'California State University-Fullerton': 1,
#  ' University of California-Davis': 1,
#  'Polytechnic Institute of Brooklyn': 1,
#  ' Michigan State University': 1,
#  'University of Minnesota-Minneapolis': 1,
#  'Emory University': 1,
#  'Punjab Engineering College': 1,
#  'University of Wisconsin-Madison': 1,
#  ' Utah State University': 1,
#  ' University of Massachusetts': 1,
#  ' Webster University': 1,
#  'Air Force Institute of Technology': 1,
#  'Loyola College': 1,
#  'Tennessee Polytechnic Institute': 1,
#  'Ohio State University': 1,
#  ' Auburn University': 1,
#  ' University of Alabama-Huntsville': 1,
#  'University of Alabama at Birmingham': 1,
#  'California State University': 1,
#  'LeMoyne College': 1,
#  'Washington State University': 1,
#  ' Queen’s University-Canada': 1,
#  'Cambridge University': 1,
#  'Texas A&M University': 1,
#  ' University of New Mexico': 1,
#  'State University of New York': 1,
#  'Vanderbilt University': 1,
#  ' University of Pennsylvania': 1,
#  'California Polytechnic Institute': 1,
#  'Muskingum College': 1,
#  'Southeast Missouri State': 1,
#  'University of Vermont': 1,
#  ' University of Chicago': 1,
#  ' Webster College': 1,
#  'University of Houston': 1,
#  ' Texas Tech University': 1,
#  'Tufts University': 1,
#  ' University of California': 1,
#  'nan': 1,
#  'University of the Pacific': 1,
#  'Northwest Nazarene College': 1,
#  'Southern Illinois University-Carbondale': 1,
#  ' Florida State Institute of Technology': 1,
#  'Southern Methodist University': 1,
#  ' Baylor University': 1,
#  'California State University-Northridge': 1,
#  'Tarleton State University': 1,
#  ' Texas Woman’s University': 1,
#  'Tulane University': 1,
#  ' California State University': 1,
#  'State University of New York at Buffalo': 1,
#  ' Northeastern University': 1,
#  'Missouri Southern State College': 1,
#  ' University of Alabama': 1,
#  'State University of New York Maritime College': 1,
#  'College of the Holy Cross': 1,
#  'Embry-Riddle University': 1,
#  ' US Army War College': 1,
#  ' University of Oklahoma': 1,
#  'Brown University': 1,
#  ' University of California-Berkley': 1,
#  ' University of Minnesota': 1,
#  ' University of North Carolina': 1,
#  ' Wayne State University': 1,
#  'University College at Cardiff': 1,
#  'Washington & Lee University': 1,
#  'Davidson College': 1,
#  ' Wake Forest University': 1,
#  'Columbia University': 1,
#  ' University of California-San Diego': 1,
#  'Framingham State College': 1,
#  ' Bowie State College': 1,
#  'US Naval Postgraduate School': 1,
#  'North Carolina A&T State College': 1,
#  'Wellesley College': 1,
#  'University of Richmond': 1,
#  'Whitman College': 1,
#  ' University of Alabama-Birmingham': 1,
#  ' New York University': 1,
#  ' Marietta College': 1,
#  ' University of Kentucky': 1,
#  'Yale University': 1,
#  'Dartmouth College': 1,
#  'University of North Dakota': 1,
#  'Williams College': 1,
#  'San Diego State University': 1,
#  'University of Texas-El Paso': 1,
#  'Baldwin Wallace College': 1,
#  'Youngstown State University': 1,
#  'University of Cambridge': 1,
#  ' Pennsylvania State University': 1,
#  ' University of North Texas': 1,
#  'Oklahoma Baptist University': 1,
#  ' Oklahoma State University': 1,
#  'University of Texas-Dallas': 1,
#  'University of Pennsylvania': 1,
#  'University of Missouri': 1,
#  'Indiana University of Pennsylvania': 1,
#  ' Medical College of Pennsylvania': 1,
#  'University of California-Davis': 1,
#  'University of California-San Diego': 1,
#  'City College of New York': 1,
#  'Northeastern University': 1,
#  'University of Edinburgh': 1,
#  ' Leeds University': 1,
#  'University of Minnesota': 1,
#  'University of Southern Mississippi': 1,
#  'Embry-Riddle Aeronautical University': 1,
#  'University of California-Santa Cruz': 1,
#  ' Dalhousie University': 1,
#  ' Florida Atlantic University': 1,
#  ' University of Hartford': 1,
#  'University of Adelaide': 1,
#  'Case Western Reserve University': 1,
#  'University of North Carolina': 1,
#  'Southeastern Massachusetts University': 1,
#  'Delft University of Technology': 1,
#  ' University of Delaware': 1,
#  'Saint John’s University': 1,
#  'Kent State University': 1,
#  ' John Carroll University': 1,
#  'University of California at Los Angeles': 1,
#  'Iowa Wesleyan College': 1,
#  'Western Kentucky University': 1,
#  'Tennessee Technological University': 1,
#  'Rensselaer Polytechnic Institute': 1,
#  ' Indiana University': 1,
#  ' University of Texas-Austin': 1}

# %%
# Initialize limit 
N = 10
    
# Using islice() + items() 
# Get first N items in dictionary 
out = dict(itertools.islice(new.items(), N)) 
        
# printing result  
print(out)
# Out:
# {'US Naval Academy': 52, 'US Air Force Academy': 38, ' US Naval Postgraduate School': 31, ' MIT': 24, 'US Military Academy': 18, 'Purdue University': 15, ' Stanford University': 15, 'MIT': 12, ' Georgia Institute of Technology': 10, ' University of Colorado': 8}

# %%
nasa_astronaut_dataset

nasa_astronaut_dataset["Birth Date"] = nasa_astronaut_dataset["Birth Date"].astype(float)
nasa_astronaut_dataset.dtypes


for i in range(len(nasa_astronaut_dataset.iloc[:,1])):
    if nasa_astronaut_dataset.iloc[i,1] == 1984.0:
        print(nasa_astronaut_dataset.iloc[i,0])
    pass

nasa_astronaut_dataset["Selection Age"] = nasa_astronaut_dataset["Selection Year"] - nasa_astronaut_dataset["Birth Date"]

nasa_astronaut_dataset
# Out:
# James C. Adamson
# Ellen S. Baker
# Mark N. Brown
# Kenneth D. Cameron
# Manley Lanier Carter Jr.
# John H. Casper
# Frank L. Culbertson Jr.
# Sidney M. Gutierrez
# L. Blaine Hammond Jr.
# Marsha S. Ivins
# Mark C. Lee
# G. David Low
# Michael J. McCulley
# James A. McDivitt
# William M. Shepherd
# Kathryn C. Thornton
# Charles Lacy Veach
# James D. Wetherbee
#                       Name    Year  Group   Status  Birth Date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active      1967.0
# 1           Loren W. Acton     NaN    NaN  Retired      1936.0
# 2         James C. Adamson  1984.0   10.0  Retired      1946.0
# 3          Thomas D. Akers  1987.0   12.0  Retired      1951.0
# 4              Buzz Aldrin  1963.0    3.0  Retired      1930.0
# ..                     ...     ...    ...      ...         ...
# 352          David A. Wolf  1990.0   13.0  Retired      1956.0
# 353  Neil W. Woodward III   1998.0   17.0  Retired      1962.0
# 354       Alfred M. Worden  1966.0    5.0  Retired      1932.0
# 355          John W. Young  1962.0    2.0  Retired      1930.0
# 356        George D. Zamka  1998.0   17.0  Retired      1962.0
#
#            Birth Place Gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# 4        Montclair, NJ   Male
# ..                 ...    ...
# 352   Indianapolis, IN   Male
# 353        Chicago, IL   Male
# 354        Jackson, MI   Male
# 355  San Francisco, CA   Male
# 356    Jersey City, NJ   Male
#
#                                             Alma Mater  \
# 0    University of California-Santa Barbara; Univer...
# 1     Montana State University; University of Colorado
# 2            US Military Academy; Princeton University
# 3                         University of Missouri-Rolla
# 4                             US Military Academy; MIT
# ..                                                 ...
# 352              Purdue University; Indiana University
# 353  MIT; University of Texas-Austin; George Washin...
# 354        US Military Academy; University of Michigan
# 355                    Georgia Institute of Technology
# 356  US Naval Academy; Florida Institute of Technology
#
#           Undergraduate Major                            Graduate Major  ...  \
# 0                     Geology                                   Geology  ...
# 1         Engineering Physics                             Solar Physics  ...
# 2                 Engineering                     Aerospace Engineering  ...
# 3         Applied Mathematics                       Applied Mathematics  ...
# 4      Mechanical Engineering                              Astronautics  ...
# ..                        ...                                       ...  ...
# 352    Electrical Engineering                                  Medicine  ...
# 353                   Physics              Physics; Business Management  ...
# 354          Military Science  Aeronautical & Astronautical Engineering  ...
# 355  Aeronautical Engineering                                       NaN  ...
# 356               Mathematics                    Engineering Management  ...
#
#                Military Branch Space Flights  Space Flight (hr)  Space Walks  \
# 0                          NaN             2               3307            2
# 1                          NaN             1                190            0
# 2            US Army (Retired)             2                334            0
# 3       US Air Force (Retired)             4                814            4
# 4       US Air Force (Retired)             2                289            2
# ..                         ...           ...                ...          ...
# 352                        NaN             3               4044            7
# 353                    US Navy             0                  0            0
# 354     US Air Force (Retired)             1                295            1
# 355          US Navy (Retired)             6                835            3
# 356  US Marine Corps (Retired)             2                692            0
#
#      Space Walks (hr)                                           Missions  \
# 0                13.0             STS-119 (Discovery), ISS-31/32 (Soyuz)
# 1                 0.0                              STS 51-F (Challenger)
# 2                 0.0               STS-28 (Columbia), STS-43 (Atlantis)
# 3                29.0  STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...
# 4                 8.0                               Gemini 12, Apollo 11
# ..                ...                                                ...
# 352              41.0  STS-58 (Columbia). STS-86/89 (Atlantis/Endeavo...
# 353               0.0                                                NaN
# 354               0.5                                          Apollo 15
# 355              20.0  Gemini 3, Gemini 10, Apollo 10, Apollo 16, STS...
# 356               0.0            STS-120 (Discovery), STS-130 (Endeavor)
#
#     Death Date Death Mission Selection Year  Selection Age
# 0          NaN           NaN         2004.0           37.0
# 1          NaN           NaN            NaN            NaN
# 2          NaN           NaN         1984.0           38.0
# 3          NaN           NaN         1987.0           36.0
# 4          NaN           NaN         1963.0           33.0
# ..         ...           ...            ...            ...
# 352        NaN           NaN         1990.0           34.0
# 353        NaN           NaN         1998.0           36.0
# 354        NaN           NaN         1966.0           34.0
# 355        NaN           NaN         1962.0           32.0
# 356        NaN           NaN         1998.0           36.0
#
# [357 rows x 21 columns]

# %%
import functions as f

# %%
nasa_astronaut_dataset = f.get_data()

f.change_dates(nasa_astronaut_dataset)

f.add_selection_age(nasa_astronaut_dataset)

f.highest_flight_hours(nasa_astronaut_dataset)

filtered = f.filter_by_year(nasa_astronaut_dataset, 1980, 1990)

new = f.frequency(nasa_astronaut_dataset, 7)

f.tops(new, 10)
# Out:
# {'US Naval Academy': 52,
#  'US Air Force Academy': 38,
#  ' US Naval Postgraduate School': 31,
#  ' MIT': 24,
#  'US Military Academy': 18,
#  'Purdue University': 15,
#  ' Stanford University': 15,
#  'MIT': 12,
#  ' Georgia Institute of Technology': 10,
#  ' University of Colorado': 8}

# %%
gender_military, gender_occurrence_name = f.gender_military(nasa_astronaut_dataset)

f.most_space_walks(nasa_astronaut_dataset)

f.average(nasa_astronaut_dataset)
# Out:
# 1249.266106442577
